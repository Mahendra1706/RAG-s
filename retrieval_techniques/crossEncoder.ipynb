# %% [markdown]
# ## Reranking using cross encoder

# %%
# !pip install flashrank
# Out:
# Collecting flashrank
#   Downloading FlashRank-0.2.10-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tokenizers in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from flashrank) (0.22.1)
# Requirement already satisfied: onnxruntime in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from flashrank) (1.23.2)
# Requirement already satisfied: numpy in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from flashrank) (2.4.0)
# Requirement already satisfied: requests in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from flashrank) (2.32.5)
# Requirement already satisfied: tqdm in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from flashrank) (4.67.1)
# Requirement already satisfied: coloredlogs in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from onnxruntime->flashrank) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from onnxruntime->flashrank) (25.12.19)
# Requirement already satisfied: packaging in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from onnxruntime->flashrank) (24.2)
# Requirement already satisfied: protobuf in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from onnxruntime->flashrank) (6.33.2)
# Requirement already satisfied: sympy in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from onnxruntime->flashrank) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime->flashrank) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from requests->flashrank) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from requests->flashrank) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from requests->flashrank) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from requests->flashrank) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from sympy->onnxruntime->flashrank) (1.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from tokenizers->flashrank) (1.2.3)
# Requirement already satisfied: filelock in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (6.0.3)
# Requirement already satisfied: shellingham in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.5.4)
# Requirement already satisfied: typer-slim in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.20.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (4.15.0)
# Requirement already satisfied: anyio in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /home/luffy/RAG/.venv/lib/python3.12/site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (8.3.1)
# Downloading FlashRank-0.2.10-py3-none-any.whl (14 kB)
# Installing collected packages: flashrank
# Successfully installed flashrank-0.2.10

# %%
from flashrank import Ranker, RerankRequest
from typing import List, Dict, Any

# %%
class RerankProcessor:

    def __init__(self, model_name: str = "ms-marco-TinyBERT-L-2-v2"):
        """
        Initializes the FlashRank engine.
        Model options: 'ms-marco-MiniLM-L-12-v2' (More accurate) 
        or 'ms-marco-TinyBERT-L-2-v2' (Faster/Smaller).
        """
        self.ranker = Ranker(model_name=model_name, cache_dir="/tmp/")

    def refine_context(
            self,
            query: str,
            documents: List[Dict[str, Any]],
            threshold: float = 0.1,
            top_k: int = 3
    ) -> List[Dict[str, Any]]:
        
        if not documents:
            return []
        
        rerank_request = RerankRequest(query=query, passages=documents)

        rerank_response = self.ranker.rerank(rerank_request)

        refined_results = [
            doc for doc in rerank_response
            if doc['score'] >= threshold
        ]

        sorted_docs = sorted(refined_results, key=lambda x: x['score'], reverse=True)

        return sorted_docs[:top_k]

# %%
# documents

raw_retrieved_data = [
    {"id": "DOC_001", "text": "To reset your password, click the 'Forgot Password' link on the login page.", "meta": "auth_docs"},
    {"id": "DOC_002", "text": "The company kitchen provides free coffee and snacks for all employees.", "meta": "office_policy"},
    {"id": "DOC_003", "text": "Security protocols require a password reset every 90 days for administrative accounts.", "meta": "security_manual"},
    {"id": "DOC_004", "text": "Passwords must be at least 12 characters long and contain one special symbol.", "meta": "security_manual"},
    {"id": "DOC_005", "text": "The annual holiday party is scheduled for December 15th at the grand ballroom.", "meta": "events"}
]

# %%
rerank = RerankProcessor()

result = rerank.refine_context(
    query="How do I reset my password?",
    documents=raw_retrieved_data,
    threshold=0.2,
    top_k=2
)

# %%
print(result)
# Out:
# [{'id': 'DOC_001', 'text': "To reset your password, click the 'Forgot Password' link on the login page.", 'meta': 'auth_docs', 'score': np.float32(0.99954754)}, {'id': 'DOC_003', 'text': 'Security protocols require a password reset every 90 days for administrative accounts.', 'meta': 'security_manual', 'score': np.float32(0.98111445)}]

# %%
import pprint

pprint.pprint(result)
# Out:
# [{'id': 'DOC_001',
#   'meta': 'auth_docs',
#   'score': np.float32(0.99954754),
#   'text': "To reset your password, click the 'Forgot Password' link on the "
#           'login page.'},
#  {'id': 'DOC_003',
#   'meta': 'security_manual',
#   'score': np.float32(0.98111445),
#   'text': 'Security protocols require a password reset every 90 days for '
#           'administrative accounts.'}]
